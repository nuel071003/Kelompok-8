# %% [markdown]
# <a href="https://colab.research.google.com/github/nuel071003/Kelompok-8/blob/main/UAS_MeachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Halllo
# Perkenalkan Kami dari Kelompok La Celeste Team
# Akan mempresentasikan Tugas Kami pada Mata Kuliah Kecerdasan Buatan yaitu Prediksi Keseluruhan Pemain Sepak Bola Menggunakan Random Forest
# Berikut ini nama-nama Kelompok Kami :
# 1. Hizkia Imanuel Simanjuntak
# 2. Clif Igobula
# 3. Putri Novriska Iba
# 4. Fauzan Marvin J Sawardany
#
# Algoritma yang kami gunakan pada Kecerdasan Buatan saat ini adalah Random Forest

# %%
# Pemrosesan Data
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# Mengakses Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Analisis Data
foot= pd.read_csv("/content/drive/MyDrive/Dataset/fifa_players.csv")

# %%
# Analisis Data pada Pemain Bola
foot
# Out:
#                  name                         full_name birth_date   age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987  31.0
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992  27.0
# 2            P. Pogba                        Paul Pogba  3/15/1993  25.0
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991  27.0
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991  27.0
# ...               ...                               ...        ...   ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993  25.0
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996  23.0
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996  22.0
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997  21.0
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999  19.0
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
# explorasi data deskripsi
print(foot.describe())
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.795400e+04   17954.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.646481e+06   21844.377245                       0.392168
# ...

# %%
# explorasi data pada Info
print(foot.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  float64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  float64
#  9   potential                      17954 non-null  float64
#  10  value_euro                     17954 non-null  float64
#  11  wage_euro                      17954 non-null  float64
# ...

# %%
# Mengisi semua kolom numerik dengan rata-rata masing-masing kolom
imputer_mean = SimpleImputer(strategy='mean')
foot[foot.select_dtypes(include=['float64', 'int64']).columns] = imputer_mean.fit_transform(foot.select_dtypes(include=['float64', 'int64']))

# %%
# Mempersiapkan Fitur dan Target untuk Model
x = foot.drop(columns=['overall_rating','name','full_name','positions','nationality','birth_date','preferred_foot','body_type','national_team_position','national_team'])
y = foot['overall_rating']

# %%
# Membagi Data Pelatihan dan Pengujian Model
from sklearn.model_selection import train_test_split
train_x, test_x , train_y, test_y = train_test_split(x, y, test_size = 0.10)

# %%
# Memilih Kolom Numerik dari Dataframe
num = foot.select_dtypes('number').reset_index(drop = True)

# %%
# Inisialisasi Random Forest
clf = RandomForestClassifier(n_estimators=1200, random_state=80)

# %%
# Melatih Model Random Forest dengan Data
new_var = clf.fit(train_x, train_y)
new_var
# Out:
# RandomForestClassifier(n_estimators=1200, random_state=80)

# %%
# Hasil Prediksi Random Forest
predictions = clf.predict(test_x)

# %%
# Pengujian Data dan Akurasi Data
accuracy = accuracy_score(test_y, predictions)
print(f"Accuracy: {accuracy:2f}")
# Out:
# Accuracy: 0.687639
